# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r"C:\Users\ELCOT\Documents\Data Science\Projects\Heart Disease Prediction\Heart_Disease_Prediction.csv")
data
# Out:
#      index  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 0        0   70    1                4  130          322             0
# 1        1   67    0                3  115          564             0
# 2        2   57    1                2  124          261             0
# 3        3   64    1                4  128          263             0
# 4        4   74    0                2  120          269             0
# ..     ...  ...  ...              ...  ...          ...           ...
# 265    265   52    1                3  172          199             1
# 266    266   44    1                2  120          263             0
# 267    267   56    0                2  140          294             0
# 268    268   57    1                4  140          192             0
# 269    269   67    1                4  160          286             0
#
#      EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# ...

# %%
df=data.drop(columns='index', axis=1)
#after removing a column, u should used to store the data in separate element like x=df.drop(........)

# %%
df.columns=['Age','Sex','Chest Pain Type','BP','Cholestral','FBS','EKG','Max HR','Exercise Angina','ST Depression','Slope of ST','Number of Vessels Fluro','Thallium','Heart Disease']

# %% [markdown]
# # Data Processing

# %%
df.head()
# Out:
#    Age  Sex  Chest Pain Type   BP  Cholestral  FBS  EKG  Max HR  \
# 0   70    1                4  130         322    0    2     109
# 1   67    0                3  115         564    0    2     160
# 2   57    1                2  124         261    0    0     141
# 3   64    1                4  128         263    0    0     105
# 4   74    0                2  120         269    0    2     121
#
#    Exercise Angina  ST Depression  Slope of ST  Number of Vessels Fluro  \
# 0                0            2.4            2                        3
# 1                0            1.6            2                        0
# 2                0            0.3            1                        0
# 3                1            0.2            2                        1
# 4                1            0.2            1                        1
#
#    Thallium Heart Disease
# 0         3      Presence
# 1         7       Absence
# 2         7      Presence
# 3         7       Absence
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest Pain Type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholestral               270 non-null    int64
#  5   FBS                      270 non-null    int64
#  6   EKG                      270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise Angina          270 non-null    int64
#  9   ST Depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of Vessels Fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    object
# ...

# %%
df.describe()
# Out:
#               Age         Sex  Chest Pain Type          BP  Cholestral  \
# count  270.000000  270.000000       270.000000  270.000000  270.000000
# mean    54.433333    0.677778         3.174074  131.344444  249.659259
# std      9.109067    0.468195         0.950090   17.861608   51.686237
# min     29.000000    0.000000         1.000000   94.000000  126.000000
# 25%     48.000000    0.000000         3.000000  120.000000  213.000000
# 50%     55.000000    1.000000         3.000000  130.000000  245.000000
# 75%     61.000000    1.000000         4.000000  140.000000  280.000000
# max     77.000000    1.000000         4.000000  200.000000  564.000000
#
#               FBS         EKG      Max HR  Exercise Angina  ST Depression  \
# count  270.000000  270.000000  270.000000       270.000000      270.00000
# mean     0.148148    1.022222  149.677778         0.329630        1.05000
# std      0.355906    0.997891   23.165717         0.470952        1.14521
# ...

# %%
df.shape
# Out:
# (270, 14)

# %%
df.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest Pain Type            0
# BP                         0
# Cholestral                 0
# FBS                        0
# EKG                        0
# Max HR                     0
# Exercise Angina            0
# ST Depression              0
# Slope of ST                0
# Number of Vessels Fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Chest Pain Type', 'BP', 'Cholestral', 'FBS', 'EKG',
#        'Max HR', 'Exercise Angina', 'ST Depression', 'Slope of ST',
#        'Number of Vessels Fluro', 'Thallium', 'Heart Disease'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age                          int64
# Sex                          int64
# Chest Pain Type              int64
# BP                           int64
# Cholestral                   int64
# FBS                          int64
# EKG                          int64
# Max HR                       int64
# Exercise Angina              int64
# ST Depression              float64
# Slope of ST                  int64
# Number of Vessels Fluro      int64
# Thallium                     int64
# Heart Disease               object
# dtype: object

# %%
more_BP=df['BP']>=120
more_BP.value_counts()
# Out:
# True     213
# False     57
# Name: BP, dtype: int64

# %%
more_Cholestral=df['Cholestral']>=200
more_Cholestral.value_counts()
# Out:
# True     231
# False     39
# Name: Cholestral, dtype: int64

# %%
more_FBS=df['FBS']>=1
more_FBS.value_counts()
# Out:
# False    230
# True      40
# Name: FBS, dtype: int64

# %%
men_with_disease=df['Sex']==1

print('Men with Heart Attack:',men_with_disease.value_counts())
# Out:
# Men with Heart Attack: True     183
# False     87
# Name: Sex, dtype: int64

# %% [markdown]
# # Stastical Analysis

# %%
mean=np.mean(df)
mean
# Out:
# Age                         54.433333
# Sex                          0.677778
# Chest Pain Type              3.174074
# BP                         131.344444
# Cholestral                 249.659259
# FBS                          0.148148
# EKG                          1.022222
# Max HR                     149.677778
# Exercise Angina              0.329630
# ST Depression                1.050000
# Slope of ST                  1.585185
# Number of Vessels Fluro      0.670370
# Thallium                     4.696296
# dtype: float64

# %%
med=np.median(df.Age)
med
# Out:
# 55.0

# %%
np.percentile(df.Age,50)
# Out:
# 55.0

# %%
np.quantile(df.Age,0.25)
# Out:
# 48.0

# %%
np.percentile(df.Age,10)
# Out:
# 42.0

# %%
np.percentile(df.Age,100)
# Out:
# 77.0

# %%
range=np.percentile(df.Age,75)-np.percentile(df.Age,25)
range
# Out:
# 13.0

# %%
var=np.var(df)
var
# Out:
# Age                          82.667778
# Sex                           0.218395
# Chest Pain Type               0.899328
# BP                          317.855432
# Cholestral                 2661.572785
# FBS                           0.126200
# EKG                           0.992099
# Max HR                      534.662840
# Exercise Angina               0.220974
# ST Depression                 1.306648
# Slope of ST                   0.376077
# Number of Vessels Fluro       0.887641
# Thallium                      3.752209
# dtype: float64

# %%
sd=np.std(df)
sd
# Out:
# Age                         9.092182
# Sex                         0.467328
# Chest Pain Type             0.948329
# BP                         17.828501
# Cholestral                 51.590433
# FBS                         0.355247
# EKG                         0.996042
# Max HR                     23.122778
# Exercise Angina             0.470079
# ST Depression               1.143087
# Slope of ST                 0.613251
# Number of Vessels Fluro     0.942147
# Thallium                    1.937062
# dtype: float64

# %%
from scipy.stats import skew,kurtosis,pearsonr
skewness=skew(df.Cholestral)
skewness
# Out:
# 1.1771344865188054

# %%
kurt=kurtosis(df.BP)
kurt
# Out:
# 0.8839505347799719

# %% [markdown]
# # EDA

# %%
#What is the distribution of the human beings having heart disease in the dataset?
print(df['Heart Disease'].value_counts())
plt.pie(df['Heart Disease'].value_counts(),labels=['No','Yes'],autopct='%1.1f%%')
plt.title('Heart Disease')
plt.legend()
plt.show()
sns.countplot(x='Heart Disease',data=df)
plt.title('Heart Disease')
# Out:
# Absence     150
# Presence    120
# Name: Heart Disease, dtype: int64
# Text(0.5, 1.0, 'Heart Disease')

# %%
#What is the gender distribution among patients?
men_with_disease=(df['Sex']==1).value_counts()
print(men_with_disease)

plt.pie(df['Sex'].value_counts(),labels=['Male','Female'],autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.legend()
plt.show()
sns.countplot(x='Sex',data=df)
plt.title('Gender Distribution')
plt.legend()
plt.show()
# Out:
# True     183
# False     87
# Name: Sex, dtype: int64
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#What is the age distribution of patients in the dataset?
sns.histplot(x='Age',data=df)
plt.title('Age distribution of patients')
# Out:
# Text(0.5, 1.0, 'Age distribution of patients')

# %%
#What is the distribution of thalium stress test results among patients?
sns.countplot(x='Thallium',data=df)
plt.title('Thalium distribution of patients')
# Out:
# Text(0.5, 1.0, 'Thalium distribution of patients')

# %%
#What is the distribution of cholesterol levels among patients?

sns.displot(x='Cholestral',data=df,bins=10)
plt.title('Cholestral distribution of patients')
# Out:
# Text(0.5, 1.0, 'Cholestral distribution of patients')

# %%
#How is the distribution of maximum heart rate among patients?
sns.boxplot(x='Max HR',data=df)

plt.title('Max HR distribution of patients')
# Out:
# Text(0.5, 1.0, 'Max HR distribution of patients')

# %%
#How is the distribution of resting blood pressure among patients
sns.displot(x='BP',data=df)
plt.title('BP distribution of patients')
# Out:
# Text(0.5, 1.0, 'BP distribution of patients')

# %%
#What is the distribution of the number of vessels among patients?
sns.countplot(x='Number of Vessels Fluro',data=df)

plt.title('Number of vessels distribution of patients')
# Out:
# Text(0.5, 1.0, 'Number of vessels distribution of patients')

# %%
df[['Sex','Heart Disease']]
# Out:
#      Sex Heart Disease
# 0      1      Presence
# 1      0       Absence
# 2      1      Presence
# 3      1       Absence
# 4      0       Absence
# ..   ...           ...
# 265    1       Absence
# 266    1       Absence
# 267    0       Absence
# 268    1       Absence
# 269    1      Presence
#
# [270 rows x 2 columns]

# %%
df['Number of Vessels Fluro'].value_counts()
# Out:
# 0    160
# 1     58
# 2     33
# 3     19
# Name: Number of Vessels Fluro, dtype: int64

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='Heart Disease')

# %%
#Which features are highly correlated with each other or with the target variable?
sns.heatmap(df.corr(),annot=False)
plt.title('Correlation')
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
#Is there any association between gender and age?
sns.barplot(x=df['Sex'],y=df['Age'])
plt.title('Gender and Age')
# Out:
# Text(0.5, 1.0, 'Gender and Age')

# %%
df['Chest Pain Type'].value_counts()
# Out:
# 4    129
# 3     79
# 2     42
# 1     20
# Name: Chest Pain Type, dtype: int64

# %%
df['Chest Pain Type'].value_counts().plot(kind='bar',color='red')
plt.title('Chest Pain Type')
# Out:
# Text(0.5, 1.0, 'Chest Pain Type')

# %%
#What is the distribution of the Fasting Blood Sugar among patients?
#How many people have the Fasting Blood Sugar > 120 mg/dl?
plt.pie(df['FBS'].value_counts(),labels=['FBS< 120 mg/dl','FBS > 120 mg/dl'],autopct='%1.1f%%',colors=['red','green'])
plt.title('Fasting Blood Sugar')
plt.legend()
plt.show()

# %%
#What is the gender distribution among patients diagnosed with heart disease?
sns.countplot(x='Sex',hue='Heart Disease',data=df)
plt.title('Gender distribution among patients diagnosed with heart disease')
# Out:
# Text(0.5, 1.0, 'Gender distribution among patients diagnosed with heart disease')

# %%
# Is there any association between chest pain type and heart disease diagnosis?
#In which chest pain type is more likely to have heart disease?
sns.barplot(x='Chest Pain Type',y='Heart Disease',data=df)
plt.title('Chest pain type and heart disease')
# Out:
# Text(0.5, 1.0, 'Chest pain type and heart disease')

# %%
#Do patients with heart disease have significantly higher resting blood pressure compared to those without heart disease?
sns.barplot(x='Heart Disease',y='BP',data=df)
plt.title('Resting blood pressure and heart disease')
# Out:
# Text(0.5, 1.0, 'Resting blood pressure and heart disease')

# %%
#How does the age distribution differ between males and females?
sns.histplot(x='Age',data=df,hue='Sex')
plt.title('Age distribution')
# Out:
# Text(0.5, 1.0, 'Age distribution')

# %%
#How does the target variable vary with age?
sns.barplot(x='Age',y='Heart Disease',data=df)
plt.title('Age and Heart Disease')
# Out:
# Text(0.5, 1.0, 'Age and Heart Disease')

# %%
#Is there any discernible relationship between age and cholesterol levels?
sns.scatterplot(x='Age',y='Cholestral',hue='Sex',data=df)
plt.title('Age and Cholestral')
# Out:
# Text(0.5, 1.0, 'Age and Cholestral')

# %%
#How does the presence of heart disease vary by age and gender?
sns.catplot(x='Heart Disease',y='Age',data=df)
plt.title('Age and Heart Disease')
# Out:
# Text(0.5, 1.0, 'Age and Heart Disease')

# %%
pd.crosstab(df['Sex'],df['Chest Pain Type'])
# Out:
# Chest Pain Type   1   2   3   4
# Sex
# 0                 4  16  32  35
# 1                16  26  47  94

# %%
#How does the presence of heart disease vary by chest pain type and gender?
pd.crosstab(df['Sex'],df['Chest Pain Type']).plot(kind='bar',color=['red','green','blue','yellow'])
plt.legend(['Male','Female'])

# %% [markdown]
# Which Chest pain type is most likely to have heart disease

# %%
pd.crosstab(df['Chest Pain Type'],df['Heart Disease'])
# Out:
# Heart Disease    Absence  Presence
# Chest Pain Type
# 1                     15         5
# 2                     35         7
# 3                     62        17
# 4                     38        91

# %%
#How does the presence of heart disease vary by chest pain type and gender?
pd.crosstab(df['Chest Pain Type'],df['Heart Disease']).plot(kind='pie',colors=['red','green','blue','yellow'],subplots=True)
plt.legend(['Male','Female'])
plt.title('Chest Pain Type and Heart Disease')
# Out:
# Text(0.5, 1.0, 'Chest Pain Type and Heart Disease')

# %%
#How does the presence of heart disease vary by chest pain type and gender?
sns.countplot(x='Heart Disease',hue='Chest Pain Type',data=df)
plt.title('Chest Pain Type and Heart Disease')
# Out:
# Text(0.5, 1.0, 'Chest Pain Type and Heart Disease')

# %% [markdown]
# Patients who have BP level more than 120

# %%
more_BP=df[df['BP']>120]
more_BP
# Out:
#      Age  Sex  Chest Pain Type   BP  Cholestral  FBS  EKG  Max HR  \
# 0     70    1                4  130         322    0    2     109
# 2     57    1                2  124         261    0    0     141
# 3     64    1                4  128         263    0    0     105
# 6     56    1                3  130         256    1    2     142
# 8     60    1                4  140         293    0    2     170
# ..   ...  ...              ...  ...         ...  ...  ...     ...
# 263   49    1                2  130         266    0    0     171
# 265   52    1                3  172         199    1    0     162
# 267   56    0                2  140         294    0    2     153
# 268   57    1                4  140         192    0    0     148
# 269   67    1                4  160         286    0    2     108
#
#      Exercise Angina  ST Depression  Slope of ST  Number of Vessels Fluro  \
# 0                  0            2.4            2                        3
# ...

# %%
#what is the distribution of the patient who having the BP level of more than 120 with the gender distribution?

fig=plt.figure(figsize=(30,10))
sns.countplot(x=more_BP['BP'],hue='Sex',data=df)
plt.title('People which BP level of more than 120')
# Out:
# Text(0.5, 1.0, 'People which BP level of more than 120')

# %% [markdown]
# People who have the colestral level more than 200

# %%
#what is the distribution of the patient who having the Cholestral level of more than 120 with the gender distribution?
cholestral_more_than_200=df[df['Cholestral']>200]
cholestral_more_than_200
fig=plt.figure(figsize=(20,10))
sns.histplot(x=cholestral_more_than_200['Cholestral'],hue='Sex',data=df)
plt.title('People with Cholestral level of more than 200')
# Out:
# Text(0.5, 1.0, 'People with Cholestral level of more than 200')

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler

# %%
num_col=['BP','Cholestral','Max HR','Age']
sc=StandardScaler()
df[num_col]=sc.fit_transform(df[num_col])
df
# Out:
#           Age  Sex  Chest Pain Type        BP  Cholestral  FBS  EKG    Max HR  \
# 0    1.712094    1                4 -0.075410    1.402212    0    2 -1.759208
# 1    1.382140    0                3 -0.916759    6.093004    0    2  0.446409
# 2    0.282294    1                2 -0.411950    0.219823    0    0 -0.375291
# 3    1.052186    1                4 -0.187590    0.258589    0    0 -1.932198
# 4    2.152032    0                2 -0.636310    0.374890    0    2 -1.240239
# ..        ...  ...              ...       ...         ...  ...  ...       ...
# 265 -0.267629    1                3  2.280369   -0.981951    1    0  0.532904
# 266 -1.147506    1                2 -0.636310    0.258589    0    0  1.008625
# 267  0.172309    0                2  0.485490    0.859476    0    2  0.143677
# 268  0.282294    1                4  0.485490   -1.117635    0    0 -0.072560
# 269  1.382140    1                4  1.607289    0.704409    0    2 -1.802456
#
# ...

# %% [markdown]
# #### Splitting the data into train and test

# %%
df['Heart Disease'].replace({'Presence':1,'Absence':0},inplace=True)
df
x=df[['Age','Max HR','BP','Cholestral','Chest Pain Type','FBS','EKG','Number of Vessels Fluro','Thallium','Exercise Angina','Slope of ST']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    float64
#  1   Sex                      270 non-null    int64
#  2   Chest Pain Type          270 non-null    int64
#  3   BP                       270 non-null    float64
#  4   Cholestral               270 non-null    float64
#  5   FBS                      270 non-null    int64
#  6   EKG                      270 non-null    int64
#  7   Max HR                   270 non-null    float64
#  8   Exercise Angina          270 non-null    int64
#  9   ST Depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of Vessels Fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    int64
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,df['Heart Disease'],test_size=0.2,random_state=42)

# %% [markdown]
# #### Logistic Regression

# %%
logistic=LogisticRegression()
logistic.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_logistic=logistic.predict(x_test)
acc=accuracy_score(y_test,y_pred_logistic)
print("Accuracy of logistic regression is",acc)
print("\nclassificatiopn report\n",classification_report(y_test,y_pred_logistic))
# Out:
# Accuracy of logistic regression is 0.9259259259259259
#
# classificatiopn report
#                precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94        33
#            1       0.95      0.86      0.90        21
#
#     accuracy                           0.93        54
#    macro avg       0.93      0.91      0.92        54
# weighted avg       0.93      0.93      0.93        54

# %% [markdown]
# #### Random Forest

# %%
random=RandomForestClassifier()
random.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_random=random.predict(x_test)
acc=accuracy_score(y_test,y_pred_random)
print("Accuracy of Random Forest is",acc)
print("\nclassificatiopn report\n",classification_report(y_test,y_pred_random))
# Out:
# Accuracy of Random Forest is 0.8518518518518519
#
# classificatiopn report
#                precision    recall  f1-score   support
#
#            0       0.84      0.94      0.89        33
#            1       0.88      0.71      0.79        21
#
#     accuracy                           0.85        54
#    macro avg       0.86      0.83      0.84        54
# weighted avg       0.86      0.85      0.85        54

# %% [markdown]
# #### Decision Tree

# %%
decision=DecisionTreeClassifier()
decision.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_decision=decision.predict(x_test)
acc=accuracy_score(y_test,y_pred_decision)
print("Accuracy of Decision Tree is",acc)
print("\nClassification report\n",classification_report(y_test,y_pred_decision))
# Out:
# Accuracy of Decision Tree is 0.7777777777777778
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.84      0.79      0.81        33
#            1       0.70      0.76      0.73        21
#
#     accuracy                           0.78        54
#    macro avg       0.77      0.77      0.77        54
# weighted avg       0.78      0.78      0.78        54

# %% [markdown]
# ##### K-Nearset neighbour

# %%
KNN=KNeighborsClassifier()
KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_KNN=KNN.predict(x_test)
acc=accuracy_score(y_test,y_pred_KNN)
print("Accuracy of KNN is",acc)
print("\nClassification report\n",classification_report(y_test,y_pred_KNN))
# Out:
# Accuracy of KNN is 0.8333333333333334
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87        33
#            1       0.80      0.76      0.78        21
#
#     accuracy                           0.83        54
#    macro avg       0.83      0.82      0.82        54
# weighted avg       0.83      0.83      0.83        54

# %% [markdown]
# ##### Support Vector Machine

# %%
svm=SVC(kernel='linear')
svm.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred_svm=svm.predict(x_test)
acc=accuracy_score(y_test,y_pred_svm)
print("Accuracy of SVM is",acc)
print("\nClassification report\n",classification_report(y_test,y_pred_svm))
# Out:
# Accuracy of SVM is 0.9074074074074074
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93        33
#            1       0.94      0.81      0.87        21
#
#     accuracy                           0.91        54
#    macro avg       0.92      0.89      0.90        54
# weighted avg       0.91      0.91      0.91        54

# %% [markdown]
# #### Naive Bayes

# %%
nb=GaussianNB()
nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb=nb.predict(x_test)
acc=accuracy_score(y_test,y_pred_nb)
print("Accuracy of Naive Bayes is",acc)
print("\nClassification report\n",classification_report(y_test,y_pred_nb))
# Out:
# Accuracy of Naive Bayes is 0.9074074074074074
#
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93        33
#            1       0.94      0.81      0.87        21
#
#     accuracy                           0.91        54
#    macro avg       0.92      0.89      0.90        54
# weighted avg       0.91      0.91      0.91        54

# %%
# checking the distribution of Target Variable
df['Heart Disease'].value_counts()
# Out:
# 0    150
# 1    120
# Name: Heart Disease, dtype: int64

# %% [markdown]
# # Splitting the Features and Target

# %%
X = df.drop(columns='Heart Disease', axis=1)
Y = df['Heart Disease']

# %%
print(X)
# Out:
#           Age  Sex  Chest Pain Type        BP  Cholestral  FBS  EKG    Max HR  \
# 0    1.712094    1                4 -0.075410    1.402212    0    2 -1.759208
# 1    1.382140    0                3 -0.916759    6.093004    0    2  0.446409
# 2    0.282294    1                2 -0.411950    0.219823    0    0 -0.375291
# 3    1.052186    1                4 -0.187590    0.258589    0    0 -1.932198
# 4    2.152032    0                2 -0.636310    0.374890    0    2 -1.240239
# ..        ...  ...              ...       ...         ...  ...  ...       ...
# 265 -0.267629    1                3  2.280369   -0.981951    1    0  0.532904
# 266 -1.147506    1                2 -0.636310    0.258589    0    0  1.008625
# 267  0.172309    0                2  0.485490    0.859476    0    2  0.143677
# 268  0.282294    1                4  0.485490   -1.117635    0    0 -0.072560
# 269  1.382140    1                4  1.607289    0.704409    0    2 -1.802456
#
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 265    0
# 266    0
# 267    0
# 268    0
# 269    1
# Name: Heart Disease, Length: 270, dtype: int64

# %% [markdown]
# Splitting the Data into Training data & Test Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (270, 13) (216, 13) (54, 13)

# %% [markdown]
# # Model Training

# %% [markdown]
# Here I commented Logistic Regression because I implemented and Ran in streamlit
# So I'm Trying to use XGBoost

# %% [markdown]
# Logistic Regression
# model = LogisticRegression()
#
#
# #training the LogisticRegression model with Training data
#
# model.fit(X_train, Y_train)
#
#
# #Accuracy Score
# #accuracy on training data
#
# X_train_prediction = model.predict(X_train)
#
# training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
#
# print('Accuracy on Training data : ', training_data_accuracy)
#
#
# #accuracy on test data
#
# X_test_prediction = model.predict(X_test)
#
# test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
#
# print('Accuracy on Test data : ', test_data_accuracy)

# %% [markdown]
# # XG Boost Classifier

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
#Accuracy Score
#accuracy on training data

X_train_prediction = model.predict(X_train)

training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.4675925925925926

# %%
# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# %% [markdown]
# # Building a Predictive System

# %%
input_data = (62,0,0,140,268,0,0,160,0,3.6,0,2,2)
#In input data, we should not give the target variable in the input data bcse it will be the prediction output

# change the input data to a numpy array
input_data_as_numpy_array= np.asarray(input_data)

# reshape the numpy array as we are predicting for only on instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]== 0):
  print('The Person does not have a Heart Disease')
else:
  print('The Person has Heart Disease')
# Out:
# [1]
# The Person has Heart Disease

# %% [markdown]
# # Saving the Trained Model

# %%
import pickle

# %%
filename='heart_disease_model.sav'
pickle.dump(model,open(filename,'wb'))

# %%
#loading the saved Model
loaded_model=pickle.load(open('heart_disease_model.sav','rb'))

# %%
for column in X.columns:
    print(column)
# Out:
# Age
# Sex
# Chest Pain Type
# BP
# Cholestral
# FBS
# EKG
# Max HR
# Exercise Angina
# ST Depression
# Slope of ST
# Number of Vessels Fluro
# Thallium
